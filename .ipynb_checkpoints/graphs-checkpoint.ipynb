# %%
fs = require('fs')
_ = require('underscore')

circle = JSON.parse(fs.readFileSync('circle.json', 'utf8'));
# Out:
# { objects:
#    { idvv0t6bihawin5f1:
#       { editingElement: [Object],
#         selectedParticularElement: [Object],
#         createPanelElements: [Object],
#         id: 'idvv0t6bihawin5f1',
#         __proto: [Object] },
#      idmdrqskihawin520:
#       { _master: [Object],
#         _variants: [],
#         _parent: null,
#         _children: [Object],
#         _head: [Object],
#         _isHatched: true,
#         expanded: true,
#         id: 'idmdrqskihawin520',
#         __proto: [Object] },
#      idg3rau4ihawin5f2:
#       { _master: [Object],
#         _variants: [],
#         _parent: [Object],
#         _children: [Object],
#         _head: [Object],
#         _isHatched: true,
#         id: 'idg3rau4ihawin5f2',
#         __proto: [Object] },
#      idtghu7kihawin5f3:
#       { _master: [Object],
#         _variants: [Object],
#         _parent: [Object],
#         _children: [Object],
#         _head: [Object],
#         _isHatched: true,
# ...

# %%
_.keys(circle.objects).length
# Out:
# 124

# %%
graphText = 'graph{node [shape=plaintext, fontsize=10];'
graphText += 'A -> B;'
graphText += 'B -> C [style=dotted];'
graphText += '}'

fs.writeFileSync('out.gv', graphText)
# Out:
# undefined
